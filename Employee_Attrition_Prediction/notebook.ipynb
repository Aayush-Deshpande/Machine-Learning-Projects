# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("employee_attrition_dataset.csv")
df.head()
# Out:
#    Employee_ID  Age  Gender Marital_Status Department   Job_Role  Job_Level  \
# 0            1   58  Female        Married         IT    Manager          1
# 1            2   48  Female        Married      Sales  Assistant          5
# 2            3   34    Male        Married  Marketing  Assistant          1
# 3            4   27  Female       Divorced  Marketing    Manager          1
# 4            5   40    Male       Divorced  Marketing  Executive          1
#
#    Monthly_Income  Hourly_Rate  Years_at_Company  ...  Overtime  \
# 0           15488           28                15  ...        No
# 1           13079           28                 6  ...       Yes
# 2           13744           24                24  ...       Yes
# 3            6809           26                10  ...        No
# 4           10206           52                29  ...        No
#
#    Project_Count  Average_Hours_Worked_Per_Week  Absenteeism  \
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
for i in df.columns:
    if df[i].dtype == 'O':
        print("-"*15, df[i][0], "-"*15)
        print(df[i].value_counts())
# Out:
# --------------- Female ---------------
# Gender
# Male      516
# Female    484
# Name: count, dtype: int64
# --------------- Married ---------------
# Marital_Status
# Married     348
# Single      339
# Divorced    313
# Name: count, dtype: int64
# --------------- IT ---------------
# Department
# Finance      218
# HR           211
# Sales        199
# Marketing    198
# IT           174
# Name: count, dtype: int64
# --------------- Manager ---------------
# Job_Role
# Manager      268
# Executive    252
# Analyst      251
# Assistant    229
# Name: count, dtype: int64
# --------------- No ---------------
# Overtime
# No     512
# Yes    488
# Name: count, dtype: int64
# --------------- No ---------------
# Attrition
# No     811
# Yes    189
# Name: count, dtype: int64

# %%
df.drop(columns=["Employee_ID"], axis=1, inplace=True)

# %%
X = df.drop(columns=['Attrition'], axis=1)
y = df["Attrition"]

cat_col = [features for features in X.columns if X[features].dtype == 'O']
num_col = [features for features in X.columns if X[features].dtype != 'O']

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

ct = ColumnTransformer([
    ('OneHotEncoding', OneHotEncoder(drop='first'), cat_col),
    ('StandardScaler', StandardScaler(), num_col)
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

X_train = ct.fit_transform(X_train)
X_test = ct.transform(X_test)

model = DecisionTreeClassifier(
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    class_weight='balanced',
    random_state=42
)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print(f"The Accuracy Score is: {accuracy_score(y_test, y_pred)}\n")
print(f"The Confusion Matrix is: \n{confusion_matrix(y_test, y_pred)}\n")
print(f"The Classification Report is: {classification_report(y_test, y_pred)}")
# Out:
# The Accuracy Score is: 0.444
#
# The Confusion Matrix is:
# [[ 88 124]
#  [ 15  23]]
#
# The Classification Report is:               precision    recall  f1-score   support
#
#           No       0.85      0.42      0.56       212
#          Yes       0.16      0.61      0.25        38
#
#     accuracy                           0.44       250
#    macro avg       0.51      0.51      0.40       250
# weighted avg       0.75      0.44      0.51       250
